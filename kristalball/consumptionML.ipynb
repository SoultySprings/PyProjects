# %%
import numpy as np, pandas as pd, matplotlib, plotly.express as px, matplotlib.pyplot as plt, sklearn as skl
# %matplotlib inline
matplotlib.rcParams['font.size'] = 16
matplotlib.rcParams['figure.figsize'] = (10,10)
df = pd.read_csv('consdata.csv')

# %%
df.head()
# Out:
#   Date Time Served       Bar Name Alcohol Type      Brand Name  \
# 0   1/1/2023 19:35    Smith's Bar          Rum  Captain Morgan
# 1   1/1/2023 10:07    Smith's Bar         Wine     Yellow Tail
# 2   1/1/2023 11:26  Johnson's Bar        Vodka      Grey Goose
# 3   1/1/2023 13:53  Johnson's Bar         Beer           Coors
# 4   1/1/2023 22:28  Johnson's Bar         Wine     Yellow Tail
#
#    Opening Balance (ml)  Purchase (ml)  Consumed (ml)  Closing Balance (ml)
# 0               2555.04        1824.84            0.0               4379.88
# 1               1344.37           0.00            0.0               1344.37
# 2               1034.28           0.00            0.0               1034.28
# 3               2194.53           0.00            0.0               2194.53
# 4               1020.90           0.00            0.0               1020.90

# %%
df.tail()
# Out:
#      Date Time Served        Bar Name Alcohol Type    Brand Name  \
# 6570   1/1/2024 21:03  Anderson's Bar         Beer         Coors
# 6571   1/1/2024 21:15  Anderson's Bar          Rum        Malibu
# 6572   1/1/2024 18:34  Anderson's Bar      Whiskey  Jack Daniels
# 6573   1/1/2024 22:46    Thomas's Bar        Vodka       Absolut
# 6574   1/1/2024 21:26    Thomas's Bar          Rum       Bacardi
#
#       Opening Balance (ml)  Purchase (ml)  Consumed (ml)  Closing Balance (ml)
# 6570          2.467080e+03           0.00         321.06               2146.02
# 6571          8.530000e-14        1743.64         175.05               1568.59
# 6572          4.192660e+03           0.00         197.60               3995.06
# 6573          2.424950e+03           0.00         128.52               2296.43
# 6574          1.778360e+03        1195.45         572.60               2401.21

# %%
uniqueBars = df['Bar Name'].unique()
uniqueAlcohols = df['Alcohol Type'].unique()
uniqueBrandName = df['Brand Name'].unique()
print(uniqueBars)
for bar in uniqueBars:
    df_new = df[df['Bar Name'].str.contains(bar,case='False')]
    print(bar, "\n", df_new.describe())
# Out:
# ["Smith's Bar" "Johnson's Bar" "Brown's Bar" "Taylor's Bar"
#  "Anderson's Bar" "Thomas's Bar"]
# Smith's Bar
#         Opening Balance (ml)  Purchase (ml)  Consumed (ml)  \
# count           1078.000000    1078.000000    1078.000000
# mean            2998.329573     316.169045     304.929416
# std             2605.689561     585.790369     184.234694
# min                0.000000       0.000000       0.000000
# 25%              854.802500       0.000000     165.727500
# 50%             2488.360000       0.000000     303.850000
# 75%             4766.302500     510.720000     452.392500
# max            11862.520000    1989.870000    1168.310000
#
#        Closing Balance (ml)
# count           1078.000000
# mean            3009.566215
# std             2614.709938
# min                0.000000
# 25%              847.000000
# 50%             2491.655000
# 75%             4829.292500
# max            11862.520000
# Johnson's Bar
# ...

# %%
print(uniqueAlcohols)
# Out:
# ['Rum' 'Wine' 'Vodka' 'Beer' 'Whiskey']

# %%
for bar in uniqueBars:
    df_new = df[df['Bar Name'].str.contains(bar,case='False')]
    print(bar, "\n", df_new.describe())
# Out:
# Smith's Bar
#         Opening Balance (ml)  Purchase (ml)  Consumed (ml)  \
# count           1078.000000    1078.000000    1078.000000
# mean            2998.329573     316.169045     304.929416
# std             2605.689561     585.790369     184.234694
# min                0.000000       0.000000       0.000000
# 25%              854.802500       0.000000     165.727500
# 50%             2488.360000       0.000000     303.850000
# 75%             4766.302500     510.720000     452.392500
# max            11862.520000    1989.870000    1168.310000
#
#        Closing Balance (ml)
# count           1078.000000
# mean            3009.566215
# std             2614.709938
# min                0.000000
# 25%              847.000000
# 50%             2491.655000
# 75%             4829.292500
# max            11862.520000
# Johnson's Bar
#         Opening Balance (ml)  Purchase (ml)  Consumed (ml)  \
# count           1106.000000    1106.000000    1106.000000
# ...

# %%
string = "Taylor's Bar"
df_new = df[df['Bar Name'].str.contains(string,case='False')]
print(df_new.describe())
# Out:
#        Opening Balance (ml)  Purchase (ml)  Consumed (ml)  \
# count           1088.000000    1088.000000    1088.000000
# mean            1822.482803     315.958153     289.684338
# std             1984.171171     586.518584     195.228940
# min                0.000000       0.000000       0.000000
# 25%              370.622500       0.000000     140.462500
# 50%             1293.775000       0.000000     286.280000
# 75%             2515.480000     507.652500     439.735000
# max            10008.960000    1993.180000    1176.820000
#
#        Closing Balance (ml)
# count           1088.000000
# mean            1848.732638
# std             2031.093162
# min                0.000000
# 25%              366.925000
# 50%             1303.135000
# 75%             2565.980000
# max            10850.790000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6575 entries, 0 to 6574
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date Time Served      6575 non-null   object
#  1   Bar Name              6575 non-null   object
#  2   Alcohol Type          6575 non-null   object
#  3   Brand Name            6575 non-null   object
#  4   Opening Balance (ml)  6575 non-null   float64
#  5   Purchase (ml)         6575 non-null   float64
#  6   Consumed (ml)         6575 non-null   float64
#  7   Closing Balance (ml)  6575 non-null   float64
# dtypes: float64(4), object(4)
# memory usage: 411.1+ KB

# %%
df.sort_values(["Date Time Served"], ascending=True)


time = df['Date Time Served'].to_numpy()
timeRed = [s[-5:].strip() for s in time]

date = df['Date Time Served'].to_numpy()
dateRed = [s[:-6].strip() for s in date]

dfDateTime = df.copy()
dfDateTime = dfDateTime.drop(columns=['Date Time Served'])
dfDateTime['Date'] = dateRed
dfDateTime['Time'] = timeRed
dfDateTime
# Out:
#             Bar Name Alcohol Type      Brand Name  Opening Balance (ml)  \
# 0        Smith's Bar          Rum  Captain Morgan          2.555040e+03
# 1        Smith's Bar         Wine     Yellow Tail          1.344370e+03
# 2      Johnson's Bar        Vodka      Grey Goose          1.034280e+03
# 3      Johnson's Bar         Beer           Coors          2.194530e+03
# 4      Johnson's Bar         Wine     Yellow Tail          1.020900e+03
# ...              ...          ...             ...                   ...
# 6570  Anderson's Bar         Beer           Coors          2.467080e+03
# 6571  Anderson's Bar          Rum          Malibu          8.530000e-14
# 6572  Anderson's Bar      Whiskey    Jack Daniels          4.192660e+03
# 6573    Thomas's Bar        Vodka         Absolut          2.424950e+03
# 6574    Thomas's Bar          Rum         Bacardi          1.778360e+03
#
#       Purchase (ml)  Consumed (ml)  Closing Balance (ml)      Date   Time
# ...

# %%
dfBarAlcoholBrand = df.sort_values(["Bar Name", "Alcohol Type", "Brand Name"], ascending=True).copy()
dfDate = df.sort_values(["Date Time Served"], ascending=True).copy

# %%
dfDateOpenPur = df.sort_values(["Date Time Served", "Opening Balance (ml)", "Purchase (ml)"], ascending=True).copy()
dfOpenPur = df.sort_values(["Opening Balance (ml)", "Purchase (ml)"], ascending=True).copy()
dfOpenPur
# Out:
#      Date Time Served       Bar Name Alcohol Type   Brand Name  \
# 213   1/11/2023 16:55   Thomas's Bar         Beer        Coors
# 237   1/13/2023 19:17    Smith's Bar      Whiskey     Jim Beam
# 243   1/13/2023 18:09    Brown's Bar          Rum      Bacardi
# 273   1/14/2023 12:47   Thomas's Bar      Whiskey      Jameson
# 288   1/15/2023 20:17   Taylor's Bar         Wine  Yellow Tail
# ...               ...            ...          ...          ...
# 3243  6/28/2023 14:25  Johnson's Bar         Wine  Sutter Home
# 3832  7/31/2023 18:55    Smith's Bar         Wine  Yellow Tail
# 3606  7/18/2023 13:11  Johnson's Bar         Wine  Sutter Home
# 3226  6/27/2023 21:36  Johnson's Bar         Wine  Sutter Home
# 3439   7/9/2023 15:58    Smith's Bar         Wine  Yellow Tail
#
#       Opening Balance (ml)  Purchase (ml)  Consumed (ml)  Closing Balance (ml)
# 213                   0.00            0.0           0.00                  0.00
# ...

# %%
dfBarAlcoholBrand
# Out:
#       Date Time Served        Bar Name Alcohol Type   Brand Name  \
# 170     1/9/2023 10:35  Anderson's Bar         Beer    Budweiser
# 351    1/18/2023 19:37  Anderson's Bar         Beer    Budweiser
# 407    1/21/2023 18:32  Anderson's Bar         Beer    Budweiser
# 556    1/29/2023 11:18  Anderson's Bar         Beer    Budweiser
# 626     2/2/2023 15:08  Anderson's Bar         Beer    Budweiser
# ...                ...             ...          ...          ...
# 6168   12/9/2023 12:21    Thomas's Bar         Wine  Yellow Tail
# 6239  12/13/2023 13:03    Thomas's Bar         Wine  Yellow Tail
# 6262  12/14/2023 14:43    Thomas's Bar         Wine  Yellow Tail
# 6417  12/23/2023 10:41    Thomas's Bar         Wine  Yellow Tail
# 6475  12/26/2023 22:50    Thomas's Bar         Wine  Yellow Tail
#
#       Opening Balance (ml)  Purchase (ml)  Consumed (ml)  Closing Balance (ml)
# 170                2312.98           0.00         159.07               2153.91
# ...

# %%
dfAnderson = df[df['Bar Name'].str.contains("Anderson")].sort_values(["Alcohol Type", "Brand Name"], ascending=True).copy()
dfBrown = df[df['Bar Name'].str.contains("Brown")].sort_values(["Alcohol Type", "Brand Name"], ascending=True).copy()
dfSmith = df[df['Bar Name'].str.contains("Smith")].sort_values(["Alcohol Type", "Brand Name"], ascending=True).copy()
dfTaylor = df[df['Bar Name'].str.contains("Taylor")].sort_values(["Alcohol Type", "Brand Name"], ascending=True).copy()
dfThomas = df[df['Bar Name'].str.contains("Thomas")].sort_values(["Alcohol Type", "Brand Name"], ascending=True).copy()

# purchasedml = np.array[df['Purchase (ml)']]
df_negPurch = df[df['Brand Name'].str.contains('Coors')].sort_values(["Purchase (ml)"], ascending=True).copy()
df_negPurch
# Out:
#       Date Time Served        Bar Name Alcohol Type Brand Name  \
# 217    1/12/2023 12:25     Smith's Bar         Beer      Coors
# 263    1/14/2023 22:58     Brown's Bar         Beer      Coors
# 270    1/14/2023 13:09  Anderson's Bar         Beer      Coors
# 274    1/15/2023 17:12     Smith's Bar         Beer      Coors
# 287    1/15/2023 19:47    Taylor's Bar         Beer      Coors
# ...                ...             ...          ...        ...
# 2193   4/30/2023 14:16  Anderson's Bar         Beer      Coors
# 5721  11/14/2023 16:23    Thomas's Bar         Beer      Coors
# 859    2/15/2023 22:15  Anderson's Bar         Beer      Coors
# 3379    7/5/2023 20:37    Thomas's Bar         Beer      Coors
# 5041   10/7/2023 21:02    Taylor's Bar         Beer      Coors
#
#       Opening Balance (ml)  Purchase (ml)  Consumed (ml)  Closing Balance (ml)
# 217                3409.99           0.00         205.42               3204.57
# ...

# %%
print(uniqueAlcohols)
print(uniqueBrandName)
print(uniqueBars)
# Out:
# ['Rum' 'Wine' 'Vodka' 'Beer' 'Whiskey']
# ['Captain Morgan' 'Yellow Tail' 'Grey Goose' 'Coors' 'Jim Beam' 'Absolut'
#  'Jack Daniels' 'Sutter Home' 'Miller' 'Bacardi' 'Malibu' 'Jameson'
#  'Smirnoff' 'Budweiser' 'Heineken' 'Barefoot']
# ["Smith's Bar" "Johnson's Bar" "Brown's Bar" "Taylor's Bar"
#  "Anderson's Bar" "Thomas's Bar"]

# %%
barName = {"Anderson's Bar":0,"Brown's Bar":1,"Johnson's Bar":2,"Smith's Bar":3,"Taylor's Bar":4,"Thomas's Bar":5}
alcoholType = {'Beer':0,'Rum':1,'Vodka':2,'Whiskey':3,'Wine':4}
brandName = {'Budweiser':0, 'Coors':1, 'Heineken':2, 'Miller':3, 'Bacardi':4, 'Captain Morgan':5,
 'Malibu':6, 'Absolut':7, 'Grey Goose':8, 'Smirnoff':9, 'Jack Daniels':10, 'Jameson':11, 'Jim Beam':12,
 'Barefoot':13, 'Yellow Tail':14}

df_new2 = df.copy()

barName_numeric = df["Bar Name"].map(barName)
alcoholType_numeric = df["Alcohol Type"].map(alcoholType)
brandName_numeric = df["Brand Name"].map(brandName)

df['Purchase (ml)'].corr(barName_numeric)
# Out:
# np.float64(-0.0029358546515160636)

# %%
df_new2= df.drop(columns=['Bar Name', 'Alcohol Type', 'Brand Name', 'Date Time Served'])
df_new2['BarNumeric']= barName_numeric
df_new2['AlcoholNumeric']= alcoholType_numeric
df_new2['BrandNumeric']= brandName_numeric

# %%
df_new2.corr()
# Out:
#                       Opening Balance (ml)  Purchase (ml)  Consumed (ml)  \
# Opening Balance (ml)              1.000000      -0.015837       0.258866
# Purchase (ml)                    -0.015837       1.000000       0.111480
# Consumed (ml)                     0.258866       0.111480       1.000000
# Closing Balance (ml)              0.966686       0.227826       0.201699
# BarNumeric                       -0.083647      -0.002936      -0.026739
# AlcoholNumeric                    0.110881       0.000823      -0.033068
# BrandNumeric                      0.072762       0.000337      -0.029725
#
#                       Closing Balance (ml)  BarNumeric  AlcoholNumeric  \
# Opening Balance (ml)              0.966686   -0.083647        0.110881
# Purchase (ml)                     0.227826   -0.002936        0.000823
# Consumed (ml)                     0.201699   -0.026739       -0.033068
# Closing Balance (ml)              1.000000   -0.081517        0.112988
# ...

# %%
figAndyBrPur = px.violin(dfAnderson,
                     x='Brand Name',
                     y='Purchase (ml)',
                     color = 'Brand Name',
                     color_discrete_sequence=px.colors.qualitative.G10,
                     title='Brands').update_layout(bargap=0.1)


figAndyPurCons = px.scatter(dfAnderson, x='Purchase (ml)', y='Consumed (ml)', color = 'Brand Name',
                     color_discrete_sequence=px.colors.qualitative.G10, title='Anderson\'s - Purchase To Consumption')
figBrownPurCons = px.scatter(dfBrown, x='Purchase (ml)', y='Consumed (ml)', color = 'Brand Name',
                     color_discrete_sequence=px.colors.qualitative.G10, title='Brown\'s - Purchase To Consumption')
figSmithPurCons = px.scatter(dfSmith, x='Purchase (ml)', y='Consumed (ml)', color = 'Brand Name',
                     color_discrete_sequence=px.colors.qualitative.G10, title='Smith\'s - Purchase To Consumption')
figTayPurCons = px.scatter(dfTaylor, x='Purchase (ml)', y='Consumed (ml)', color = 'Brand Name',
                     color_discrete_sequence=px.colors.qualitative.G10, title='Taylor\'s - Purchase To Consumption')
figThomasPurCons = px.scatter(dfThomas, x='Purchase (ml)', y='Consumed (ml)', color = 'Brand Name',
                     color_discrete_sequence=px.colors.qualitative.G10, title='Thomas\'s - Purchase To Consumption')



figAndyBrPur = px.histogram(dfAnderson, x='Brand Name', y='Purchase (ml)', marginal='box',
                     color = 'Brand Name', color_discrete_sequence=px.colors.qualitative.G10, title='Brands').update_layout(bargap=0.1)
figBrownBrPur = px.histogram(dfBrown, x='Brand Name', y='Purchase (ml)', marginal='box',
                     color = 'Brand Name', color_discrete_sequence=px.colors.qualitative.G10, title='Brands').update_layout(bargap=0.1)
figSmithBrPur = px.histogram(dfSmith, x='Brand Name', y='Purchase (ml)', marginal='box',
                     color = 'Brand Name', color_discrete_sequence=px.colors.qualitative.G10, title='Brands').update_layout(bargap=0.1)
figTayBrPur = px.histogram(dfTaylor, x='Brand Name', y='Purchase (ml)', marginal='box',
                     color = 'Brand Name', color_discrete_sequence=px.colors.qualitative.G10, title='Brands').update_layout(bargap=0.1)
figThomBrPur = px.histogram(dfThomas, x='Brand Name', y='Purchase (ml)', marginal='box',
                     color = 'Brand Name', color_discrete_sequence=px.colors.qualitative.G10, title='Brands').update_layout(bargap=0.1)


figAndyBrPur.show()
figBrownBrPur.show()
figSmithBrPur.show()
figTayBrPur.show()
figThomBrPur.show()
print("=================================================================================================================")
figAndyPurCons.show()
figBrownPurCons.show()
figSmithPurCons.show()
figTayPurCons.show()
figThomasPurCons.show()

# %%
figAndyBrCons = px.histogram(dfAnderson,
                     x='Brand Name',
                     y='Consumed (ml)',
                     marginal='box',
                     color = 'Brand Name',
                     color_discrete_sequence=px.colors.qualitative.G10,
                     title='Brands').update_layout(bargap=0.1)
figBrownBrCons = px.histogram(dfBrown, x='Brand Name', y='Consumed (ml)', marginal='box',
                     color = 'Brand Name', color_discrete_sequence=px.colors.qualitative.G10, title='Brands').update_layout(bargap=0.1)
figSmithBrCons = px.histogram(dfSmith, x='Brand Name', y='Consumed (ml)', marginal='box',
                     color = 'Brand Name', color_discrete_sequence=px.colors.qualitative.G10, title='Brands').update_layout(bargap=0.1)
figTayBrCons = px.histogram(dfTaylor, x='Brand Name', y='Consumed (ml)', marginal='box',
                     color = 'Brand Name', color_discrete_sequence=px.colors.qualitative.G10, title='Brands').update_layout(bargap=0.1)
figThomBrCons = px.histogram(dfThomas, x='Brand Name', y='Consumed (ml)', marginal='box',
                     color = 'Brand Name', color_discrete_sequence=px.colors.qualitative.G10, title='Brands').update_layout(bargap=0.1)

from plotly.subplots import make_subplots

figAndyBrCons.show()
figBrownBrCons.show()
figSmithBrCons.show()
figTayBrCons.show()
figThomBrCons.show()

# %%
fig4 = px.hist_frame(df,
                     x='Bar Name',
                     y='Purchase (ml)',
                     marginal='box',
                     color = 'Alcohol Type',
                     color_discrete_sequence=['Dark Blue', 'Black','Yellow','Red','Green'],
                     title='Alcohols')
fig5 = px.hist_frame(df,
                     x='Bar Name',
                     y='Consumed (ml)',
                     marginal='box',
                     color = 'Alcohol Type',
                     color_discrete_sequence=['Dark Blue', 'Black','Yellow','Red','Green'],
                     title='Alcohols')
fig4.update_layout(bargap=0.1)
fig5.update_layout(bargap=0.1)

fig4.show()
fig5.show()

# %%
fig1 = px.histogram(df, x='Date Time Served', y='Purchase (ml)', color_discrete_sequence=['Green'], title='Purchase to Date')
fig2 = px.histogram(df, x='Date Time Served', y='Opening Balance (ml)', color_discrete_sequence=['Red'], title='Opening to Date')
fig3 = px.histogram(df, x='Date Time Served', y='Closing Balance (ml)', color_discrete_sequence=['Dark Blue'], title='Closing to Date')

fig1.show()
fig2.show()
fig3.show()
